# %%
from storage import get_data_frame
from estetica import show_with_estetica, show_multiple_with_estetica

# %%
df = get_data_frame("video2")

# %%
show_with_estetica(df['time'], df['rx_wrist'], x_name = 'Tiempo (s)', y_name = 'Posición de la muñeca (m)', title = 'Posición de la muñeca en el eje X vs. Tiempo')

# %%
show_with_estetica(df['time'], df['ry_wrist'], x_name = 'Tiempo (s)', y_name = 'Posición de la muñeca (m)', title = 'Posición de la muñeca en el eje Y vs. Tiempo')

# %%
show_with_estetica(df['time'], df['vy_wrist'], x_name = 'Tiempo (s)', y_name = 'Velocidad de la muñeca (m/s)', title = 'Velocidad de la muñeca en el eje Y vs. Tiempo')

# %%
show_with_estetica(df['time'], df['ay_wrist'], x_name = 'Tiempo (s)', y_name = 'Aceleración de la muñeca (m/s^2)', title = 'Aceleración de la muñeca en el eje Y vs. Tiempo')

# %%
show_with_estetica(df['time'], df['theta_wrist'], x_name = 'Tiempo (s)', y_name = 'Ángulo en el codo (rad)', title = 'Ángulo en el codo vs Tiempo')

# %%
show_with_estetica(df['time'], df['angular_acceleration'], x_name = 'Tiempo (s)', y_name = 'Aceleración angular (rad/s²)', title = 'Aceleración angular vs Tiempo')

# %%
show_with_estetica(df['time'], df['angular_velocity'], x_name = 'Tiempo (s)', y_name = 'Velocidad angular (rad/s)', title = 'Velocidad angular vs Tiempo')

# %%
show_with_estetica(df['time'], df['force_bicep'], x_name = 'Tiempo (s)', y_name = 'Fuerza del bicep (N)', title = 'Fuerza del bicep vs. Tiempo')

# %%
show_multiple_with_estetica(df['time'], [(df['sum_moment'], 'Sum moments'), (df['moment_weight'], 'Weight moment'), (df['moment_forearm'], 'Forearm moment')], x_name = 'time (s)', y_name = 'Moment (Nm)', title = 'Moments')

# %%
show_with_estetica(df['time'], df['work_i'], x_name = 'time (s)', y_name = 'Work bicep (J)', title = 'Bicep work vs. Time')

# %%
show_multiple_with_estetica(df['time'], [(df['theta_wrist'], 'wrist angle'), (df['curve_fit_theta'], 'curve fit angle')], x_name = 'time (s)', y_name = 'angle (R)', title = 'Error Correction')

# %%
show_multiple_with_estetica(df['time'], [(df['mechanical_energy'], 'Energia Mecanica'), (df['potential_energy'], 'Energia Potencial')], x_name = 'Tiempo (s)', y_name = 'Energia (J)', title = 'Energia mecanica, potencial y cinetica vs Tiempo')

# %%
show_with_estetica(df['time'], df['work_i_from_energy'], x_name = 'time (s)', y_name = 'Work form Energy (J)', title = 'Work from Energy vs. Time')

# %%
show_multiple_with_estetica(df['time'], [(df['work_i'], 'Trabajo del bicep'), (df['work_i_from_energy'], 'Trabajo a partir de energia')], x_name = 'Tiempo (s)', y_name = 'Trabajo (J)', title = 'Trabajo vs. Tiempo')
